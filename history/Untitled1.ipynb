# %%
import os
os.getcwd()
# Out:
# '/home/jovyan/work/project/2team'

# %%
import os

base = "/home/jovyan/work/project/2team"

for root, dirs, files in os.walk(base):
    if "images" in dirs:
        print("FOUND:", os.path.join(root, "images"))

# %%
import os
base = "/home/jovyan/work/project/2team"
print(os.listdir(base))
# Out:
# ['ref', 'Untitled1.ipynb', 'Untitled.ipynb', 'dlthon-Copy1.ipynb', '.ipynb_checkpoints', 'README.md', '.git', 'desc', '.gitignore', 'dlthon.ipynb']

# %%
import os

base = "/home/jovyan/work"
target = "COCO_motorcycle (pixel).json"

for root, dirs, files in os.walk(base):
    if target in files:
        print("FOUND JSON:", os.path.join(root, target))
# Out:
# FOUND JSON: /home/jovyan/work/project/first-repository/Computer_Vision/CV03/2team/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/COCO_motorcycle (pixel).json
# FOUND JSON: /home/jovyan/work/project/first-repository/Computer_Vision/CV03/www.acmeai.tech ODataset 1 - Motorcycle Night Ride Dataset/COCO_motorcycle (pixel).json
