# %% [markdown]
# Motorcycle Night Ride (Semantic Segmentation)

# %% [markdown]
# - 실제 사진 200장
# - 라벨 사진 200장
# - 변환용 사진 200장

# %%
# $ mkdir ~/work/motorcycle
# $ pip install kaggle

# %%
# $ mkdir ~/.kaggle
# $ mv kaggle.json ~/.kaggle/kaggle.json
# $ cd ~/work/motorcycle
# $ kaggle datasets download -d sadhliroomyprime/motorcycle-night-ride-semantic-segmentation
# $ unzip motorcycle-night-ride-semantic-segmentation.zip

# %% [markdown]
# ## 과업

# %% [markdown]
# 1. 상대적으로 적은 양의 도로주행 이미지 데이터를 활용하여 multiclass semantic segmentation을 수행합니다. 충돌 시 큰 위험을 맞이하는 도로 주행 환경에 맞춰, 모델의 성능 지표를 상세하게 설정해야 합니다
# 2. CAM을 통해 오브젝트의 어느 부분이 class를 결정하는데 영향을 미쳤는지 시각화하여 확인해봅니다.
# 3. W&B를 통해 모델 학습 및 파라미터를 관리합니다.

# %% [markdown]
# ## 규칙

# %% [markdown]
# 1. 프로젝트 제출 기한내 LMS의 프로젝트 제출 스텝에서 결과 노트북의 링크를 제출해주세요.
# 2. 프로젝트 제출 스텝의 루브릭을 따라 노트북의 내용을 채워주세요.
# 3 .외부 데이터 활용은 허용하되, 제공된 데이터를 활용한 기록이 필수적으로 포함되어야 합니다.
# 4. 부정 제출 행위를 금지하고 있으며, 부정 제출 이력이 있는 경우 평가가 제한됩니다.

# %% [markdown]
# ## 평가항목

# %% [markdown]
# - 데이터 EDA와 데이터 전처리가 적절하게 이뤄졌는가?
# - Task에 알맞게 적절한 모델을 찾아보고 선정했는가?
# - 성능향상을 위해 논리적으로 접근했는가?
# - 결과 도출을 위해 여러가지 시도를 진행했는가?
# - 도출된 결론에 충분한 설득력이 있는가?
# - 적절한 metric을 설정하고 그 사용 근거 및 결과를 분석하였는가?
# - 발표가 매끄럽게 진행되었고 발표시간을 준수하였는지?

# %% [markdown]
# ## 1. 데이터 수집 및 준비 (Data Collection & Preparation)

# %%
# !pip install opencv-python
# !pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-python in /opt/conda/lib/python3.12/site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /opt/conda/lib/python3.12/site-packages (from opencv-python) (2.2.6)
# Requirement already satisfied: opencv-contrib-python in /opt/conda/lib/python3.12/site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /opt/conda/lib/python3.12/site-packages (from opencv-contrib-python) (2.2.6)

# %%
import os
import pandas as pd
import numpy as np
from pathlib import Path
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. 탐색적 데이터 분석 (EDA, Exploratory Data Analysis)

# %% [markdown]
# ## 3. 데이터 전처리 및 증강 (Preprocessing & Augmentation)

# %% [markdown]
# ## 4. 모델 설계 및 선택 (Model Architecture)

# %% [markdown]
# ## 5. 모델 학습 (Model Training)

# %% [markdown]
# ## 6. 평가 및 추론 (Evaluation & Inference)
